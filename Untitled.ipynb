# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
#data = data.drop(columns = ['city','country','statezip'], axis = 1)

# %%
data = data.join(pd.get_dummies(data.street)).drop(['street'],axis =1)
data = data.join(pd.get_dummies(data.city)).drop(['city'],axis =1)
data = data.join(pd.get_dummies(data.country)).drop(['country'],axis =1)
data = data.join(pd.get_dummies(data.statezip)).drop(['statezip'],axis =1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Columns: 4661 entries, date to WA 98354
# dtypes: bool(4647), float64(4), int64(9), object(1)
# memory usage: 20.9+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Columns: 4661 entries, date to WA 98354
# dtypes: bool(4647), float64(4), int64(9), object(1)
# memory usage: 20.9+ MB

# %%
data = data.drop(['date'],axis=1)

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['price'],axis = 1)
y = data['price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 913        2.0       1.50         1660      4680     1.0           0     0
# 783        3.0       2.50         2320     36847     2.0           0     2
# 3381       3.0       1.00         1110      8593     1.0           0     0
# 2985       3.0       1.00         1300      8160     1.0           0     0
# 1029       3.0       1.50         1080      2940     1.5           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 2612       3.0       2.75         2670      3738     1.0           0     0
# 2682       3.0       1.50         1450      7375     1.0           0     0
# 782        2.0       1.50         1070      9643     1.0           0     0
# 1561       4.0       1.75         1700      7800     1.0           0     0
# 2498       3.0       2.50         2860      4442     2.0           0     0
#
#       condition  sqft_above  sqft_basement  ...  WA 98166  WA 98168  WA 98177  \
# 913           5         830            830  ...     False     False     False
# 783           3        2320              0  ...     False     False     False
# 3381          3        1110              0  ...     False     False     False
# 2985          4        1300              0  ...     False     False     False
# 1029          4        1080              0  ...     False     False     False
# ...         ...         ...            ...  ...       ...       ...       ...
# 2612          3        1720            950  ...     False     False     False
# 2682          3        1010            440  ...     False     False     False
# 782           3        1070              0  ...     False     False     False
# 1561          5        1120            580  ...     False     False     False
# 2498          3        2860              0  ...     False     False     False
#
#       WA 98178  WA 98188  WA 98198  WA 98199  WA 98288  WA 98354     price
# 913      False     False     False     False     False     False  368000.0
# 783      False     False     False     False     False     False  437500.0
# 3381     False     False     False     False     False     False  299900.0
# 2985     False     False     False     False     False     False  237000.0
# 1029     False     False     False     False     False     False  395000.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 2612     False     False     False     False     False     False  798800.0
# 2682     False     False     False     False     False     False  402000.0
# 782      False     False     False     False     False     False  252700.0
# 1561     False     False     False     False     False     False  349000.0
# 2498     False     False     False      True     False     False  799000.0
#
# [3680 rows x 4660 columns]

# %%
train_data['bathrooms'] = np.log(train_data['bathrooms'] + 1)
train_data['sqft_above'] = np.log(train_data['sqft_above'] + 1)
train_data['sqft_living'] = np.log(train_data['sqft_living'] + 1)
train_data['view'] = np.log(train_data['view'] + 1)

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'sqft_living'}>,
#         <Axes: title={'center': 'sqft_lot'}>],
#        [<Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>,
#         <Axes: title={'center': 'condition'}>],
#        [<Axes: title={'center': 'sqft_above'}>,
#         <Axes: title={'center': 'sqft_basement'}>,
#         <Axes: title={'center': 'yr_built'}>,
#         <Axes: title={'center': 'yr_renovated'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
from sklearn.linear_model import LinearRegression

X_train , y_train = train_data.drop(['price'],axis = 1),train_data['price']

reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = (X_test).join(y_test)

test_data['bathrooms'] = np.log(test_data['bathrooms'] + 1)
test_data['sqft_above'] = np.log(test_data['sqft_above'] + 1)
test_data['sqft_living'] = np.log(test_data['sqft_living'] + 1)
test_data['view'] = np.log(test_data['view'] + 1)

# %%
X_test , y_test = test_data.drop(['price'],axis = 1),test_data['price']

# %%
reg.score(X_test,y_test)
# Out:
# -306.51484697612136
